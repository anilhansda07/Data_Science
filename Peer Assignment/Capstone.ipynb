# %% [markdown]
# <h1>Data Science Capstone Project
# <h4>This project is based on a location data.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
